# %%
import json

# %%
with open('cfr_strategies_decoded.json') as f:
    data = json.load(f)

# %%
data
# Out:
# {'P:0,C:[Gold, Fire]->(P:1': [0.5, 0.5],
#  'P:0,C:[Gold, Fire]->(P:1,A:Fire)->(P:0': [1.0, 0.0],
#  'P:0,C:[Gold, Fire]->(P:1,A:Fire)->(P:0,A:Fire)->(P:2': [0.5, 0.5],
#  'P:0,C:[Gold, Fire]->(P:1,A:Fire)->(P:0,A:Fire)->(P:2,A:NoFire)->(P:1': [0.5,
#   0.5],
#  'P:0,C:[Gold, Fire]->(P:1,A:Fire)->(P:0,A:Fire)->(P:2,A:NoFire)->(P:1,A:2)->(P:2': [0.5,
#   0.5],
#  'P:0,C:[Gold, Fire]->(P:1,A:Fire)->(P:0,A:Fire)->(P:2,A:NoFire)->(P:1,A:2)->(P:2,A:1)->(P:1': [0.5,
#   0.5],
#  'P:0,C:[Gold, Fire]->(P:1,A:Fire)->(P:0,A:Fire)->(P:2,A:NoFire)->(P:1,A:2)->(P:2,A:1)->(P:1,A:0)->(P:0': [0.0,
#   1.0],
#  'P:0,C:[Gold, Fire]->(P:1,A:Fire)->(P:0,A:Fire)->(P:2,A:NoFire)->(P:1,A:2)->(P:2,A:1)->(P:1,A:0)->(P:0,A:1)->(P:1': [0.5,
#   0.5],
#  'P:0,C:[Gold, Fire]->(P:1,A:Fire)->(P:0,A:Fire)->(P:2,A:NoFire)->(P:1,A:2)->(P:2,A:1)->(P:1,A:0)->(P:0,A:2)->(P:2': [0.5,
#   0.5],
# ...

# %%
'P:0,C:[Gold, Fire->(P:0,A:Fire)->(P:2,A:NoFire)->(P:1,A:Fire)->(P:0,A:1)->(P:1,A:2)->(P:2,A:1)->(P:1'
# Out:
# 'P:0,C:[Gold, Fire->(P:0,A:Fire)->(P:2,A:NoFire)->(P:1,A:Fire)->(P:0,A:1)->(P:1,A:2)->(P:2,A:1)->(P:1'

# %%
from random import random
'P:0,C:[Gold, Fire]->(P:0,A:Fire)->(P:0,A:Fire)->(P:2,A:NoFire)->(P:0'
'P:0,C:[Gold, Fire]->(P:0,A:Fire)->(P:0,A:Fire)->(P:2,A:NoFire)->(P:0'
st = data['P:0,C:[Gold, Fire]->(P:1,A:NoFire)->(P:2,A:Fire)->(P:0,A:NoFire)->P:0']
print(st)
if (random() <= st[0]):
    print("Fire")
else:
    print("No Fire")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[232], line 4
#       2 'P:0,C:[Gold, Fire]->(P:0,A:Fire)->(P:0,A:Fire)->(P:2,A:NoFire)->(P:0'
#       3 'P:0,C:[Gold, Fire]->(P:0,A:Fire)->(P:0,A:Fire)->(P:2,A:NoFire)->(P:0'
# ----> 4 st = data['P:0,C:[Gold, Fire]->(P:1,A:NoFire)->(P:2,A:Fire)->(P:0,A:NoFire)->P:0']
#       5 print(st)
#       6 if (random() <= st[0]):
#
# KeyError: 'P:0,C:[Gold, Fire]->(P:1,A:NoFire)->(P:2,A:Fire)->(P:0,A:NoFire)->P:0'

# %%
from random import random
'P:0,C:[Gold, Fire]->(P:1,A:Fire)->(P:0,A:Fire)->(P:2,A:NoFire)->(P:1'
st = data['P:0,C:[Gold, Gold]->(P:2,A:NoFire)->(P:2,A:Fire)->(P:1,A:Fire)->(P:2,A:0)->(P:0,A:2)->(P:2,A:1)->(P:1,A:0)->(P:0']
print(st)
if (random() <= st[0]):
    print(1)
else:
    print(2)
# Out:
# [0.0, 1.0]
# 2

# %%
if (random() <= .5):
    print(1)
else:
    print(2)
# Out:
# 2
